# %% [markdown]
# # <b> PROYECTO 2 - 3 || CIENCIA DE DATOS </b> ~ DATASET: AGUACATES
#  <picture> <img src = "https://media0.giphy.com/media/v1.Y2lkPTc5MGI3NjExOHlqcmRvZHA2c2Rya2l0MnVjaHJpdjQ5YnhjZnhqcm5tbDZjY3M1bCZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/l1J9Lxp93dUQH8wJG/giphy.gif" width = 500px>  </picture>
#  # Integrantes:
#     - Tina Maria Torres Tascon - 2259729
#     - Juan David Valencia - 2259...
#     - Miguel Ceballos - 2259...

# %%
# %pip install pandas
# %pip install numpy
# %pip install matplotlib
# %pip install seaborn
# %pip install scikit-learn
# %pip install scipy
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %% [markdown]
# # IMPORTACIONES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.preprocessing import MinMaxScaler, StandardScaler, OneHotEncoder
from sklearn.impute import KNNImputer

# %% [markdown]
# # CARGAR EL DATASET

# %%
df  = pd.read_csv('avocado.csv')
df.head()

#EL PLU DE LOS AGUACATES
#4046 - Aguacate Hass de tamaño mediano no orgánico
#4225 - Aguacate Hass de tamaño grande no orgánico
#4770 - Aguacate Hass de tamaño extra grande no orgánico
# Out:
# Running cells with 'Python 3.12.6' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.

# %%
df.describe()
# Out:
#          Unnamed: 0                           Date  AveragePrice  \
# count  18249.000000                          18249  18249.000000
# mean      24.232232  2016-08-13 23:30:43.498273792      1.405978
# min        0.000000            2015-01-04 00:00:00      0.440000
# 25%       10.000000            2015-10-25 00:00:00      1.100000
# 50%       24.000000            2016-08-14 00:00:00      1.370000
# 75%       38.000000            2017-06-04 00:00:00      1.660000
# max       52.000000            2018-03-25 00:00:00      3.250000
# std       15.481045                            NaN      0.402677
#
#        Total Volume          4046          4225          4770    Total Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean   8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04  2.396392e+05
# min    8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# ...

# %%
df.head()
# Out:
#    Unnamed: 0       Date  AveragePrice  Total Volume     4046       4225  \
# 0           0 2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1 2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2 2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3 2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4 2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region  ingreso_total  month  day year_month
# ...

# %% [markdown]
# ## Buscando valores Nulos

# %%
plt.Figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.show()

# %% [markdown]
# > [!IMPORTANTE]
# > NO hay nulos según la gráfica.

# %% [markdown]
# ## Punto 1 Gráficas ##

# %%
# añadimos la columna de ingresos. multiplicamos el precio por el volumen total
df['ingreso_total'] = df['AveragePrice'] * df['Total Volume'] 
df['Date'] = pd.to_datetime(df['Date'])
# convertimos la fecha a datetime
df['year'] = df['Date'].dt.year
df['month'] = df['Date'].dt.month
df['day'] = df['Date'].dt.day
df['year_month'] = df['Date'].dt.strftime('%Y-%m')
#eliminar la columna de fecha original
df['Date'].dropna()
df.head()
# Out:
#    Unnamed: 0       Date  AveragePrice  Total Volume     4046       4225  \
# 0           0 2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1 2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2 2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3 2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4 2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region  ingreso_total  month  day year_month
# ...

# %%
df_avocado_prices = df.groupby(['year_month'])['AveragePrice'].mean().reset_index()

#Precio de los aguacates por mes
plt.figure(figsize=(12, 6))
plt.plot(df_avocado_prices['year_month'], df_avocado_prices['AveragePrice'], marker='o', linestyle='-')
plt.title('Precio promedio de aguacates por mes')  
plt.xlabel('Mes')
plt.ylabel('Precio promedio ($)')
plt.xticks(rotation=45)

df_avocado_prices.head()
# Out:
#   year_month  AveragePrice
# 0    2015-01      1.365046
# 1    2015-02      1.326944
# 2    2015-03      1.361981
# 3    2015-04      1.383449
# 4    2015-05      1.344685

# %%
#Ingresos por mes de los aguacates
df_avocado_income = df.groupby(['year_month'])['ingreso_total'].sum().reset_index()

plt.figure(figsize=(12, 6))
plt.plot(df_avocado_income['year_month'], df_avocado_income['ingreso_total'], marker='o', linestyle='-')
plt.title('Ingresos totales por mes de aguacates')
plt.xlabel('Mes')
plt.ylabel('Ingresos totales ($) en cientos de millones')
plt.xticks(rotation=45)
plt.show()

df_avocado_income.head()
# Out:
#   year_month  ingreso_total
# 0    2015-01   3.235693e+08
# 1    2015-02   3.534159e+08
# 2    2015-03   4.303083e+08
# 3    2015-04   3.643787e+08
# 4    2015-05   4.978038e+08

# %%
#Ingresos por tipo
ingreso_por_tipo = df.groupby(['type', 'year_month'])['ingreso_total'].sum().reset_index()
plt.figure(figsize=(12, 6))

sns.lineplot(data=ingreso_por_tipo,x= 'year_month', y='ingreso_total', hue='type', marker="o")
plt.title('Ingresos totales por tipo de aguacate')
plt.xlabel('Mes')
plt.ylabel('Ingresos totales ($) en cientos de millones')
plt.xticks(rotation=45)
plt.show()

# %%
#Ingresos por tipo de aguacate
ingreso_por_tipo = df.groupby(['AveragePrice','4046','4225', '4770', 'year_month'])['ingreso_total'].sum().reset_index()

'''plt.figure(figsize=(12, 6))

sns.lineplot(data=ingreso_por_tipo,x= 'year_month', y='ingreso_total', marker="o")
plt.title('Ingresos totales por tipo de aguacate')
plt.xlabel('Mes')
plt.ylabel('Ingresos totales ($) en cientos de millones')
plt.xticks(rotation=45)
plt.show()'''

ingreso_por_tipo.head()
# Out:
#    AveragePrice        4046       4225      4770 year_month  ingreso_total
# 0          0.44      223.84    4748.88      0.00    2017-03   2.818510e+04
# 1          0.46  1200632.86  531226.65  18324.93    2017-02   1.012253e+06
# 2          0.48      717.57    4138.84      0.00    2017-03   2.442755e+04
# 3          0.49      252.79    4472.68      0.00    2017-02   2.157177e+04
# 4          0.49   738314.80  286858.37  11642.46    2015-12   5.574766e+05
